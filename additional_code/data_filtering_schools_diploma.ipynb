# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.4 MB/s eta 0:00:00
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.0)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 79.0 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.15.0)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.1 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1

# %%
import geopandas as gpd

# %%
df_school = gpd.read_file('schools_raw.geojson')
# Out:
# WARNING:fiona._env:Non closed ring detected. To avoid accepting it, set the OGR_GEOMETRY_ACCEPT_UNCLOSED_RING configuration option to NO

# %%
full_list_of_columns = df_school.columns.values.tolist()
full_list_of_columns
# Out:
# ['id',
#  '@id',
#  'access',
#  'access:conditional',
#  'addr:city',
#  'addr:country',
#  'addr:full',
#  'addr:housenumber',
#  'addr:housenumber1',
#  'addr:housenumber2',
#  'addr:place',
#  'addr:postcode',
#  'addr:quarter',
#  'addr:region',
#  'addr:street',
#  'addr:street1',
#  'addr:street2',
#  'addr:subdistrict',
#  'addr:suburb',
#  'after_school',
#  'alt_name',
#  'amenity',
#  'architect',
#  'barrier',
#  'bicycle',
#  'branch',
#  'building',
#  'building:colour',
#  'building:levels',
#  'building:material',
#  'building:part',
#  'building:parts',
#  'capacity',
#  'check_date',
#  'check_date:opening_hours',
#  'comment',
#  'comment2',
#  'construction',
#  'contact:email',
#  'contact:facebook',
#  'contact:instagram',
#  'contact:phone',
#  'contact:telegram',
#  'contact:twitter',
#  'contact:vk',
#  'contact:website',
#  'contact:website:en',
#  'contact:youtube',
#  'denomination',
#  'description',
#  'description:en',
#  'description:fr',
#  'description:ru',
#  'design:ref',
#  'disused',
#  'education',
#  'education_form:external',
#  'education_form:fulltime',
#  'education_form:parttime',
#  'education_level:preschool',
#  'education_level:primary',
#  'education_level:secondary',
#  'education_profile:biology',
#  'education_profile:chemistry',
#  'education_profile:economics',
#  'education_profile:general',
#  'education_profile:it',
#  'education_profile:languages',
#  'education_profile:mathematics',
#  'education_profile:military',
#  'education_profile:physics',
#  'education_profile:sport',
#  'education_programme:EN',
#  'education_programme:FR',
#  'education_system:ru_standard',
#  'email',
#  'fee',
#  'fence_type',
#  'fenced',
#  'fixme',
#  'full_name',
#  'grades',
#  'height',
#  'heritage',
#  'heritage:name',
#  'historic',
#  'image',
#  'int_name',
#  'internet_access',
#  'is_in:neighbourhood',
#  'isced:level',
#  'landuse',
#  'language:en',
#  'leisure',
#  'level',
#  'levels',
#  'material',
#  'min_age',
#  'mosuzedu',
#  'name',
#  '@relations',
#  'name:alt',
#  'name:de',
#  'name:en',
#  'name:etymology:wikidata',
#  'name:fi',
#  'name:fr',
#  'name:it',
#  'name:ja',
#  'name:old',
#  'name:ru',
#  'name:sv',
#  'note',
#  'official_name',
#  'old_name',
#  'old_name2',
#  'old_name:1',
#  'old_name:2',
#  'old_name:de',
#  'old_name:en',
#  'old_official_name',
#  'old_ref',
#  'old_ref:1',
#  'old_ref:2',
#  'old_website',
#  'opening_date',
#  'opening_hours',
#  'operator',
#  'operator:en',
#  'operator:ref:inn',
#  'operator:ref:kpp',
#  'operator:ref:ogrn',
#  'operator:type',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'ownership',
#  'pedagogy',
#  'phone',
#  'ref',
#  'religion',
#  'roof:angle',
#  'roof:colour',
#  'roof:height',
#  'roof:levels',
#  'roof:material',
#  'roof:shape',
#  'school',
#  'short_name',
#  'smoking',
#  'social_facility',
#  'social_facility:for',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:building:levels',
#  'sport',
#  'start_date',
#  'supervised',
#  'toilets:wheelchair',
#  'type',
#  'url',
#  'was:alt_name',
#  'was:name',
#  'website',
#  'website:en',
#  'wheelchair',
#  'wheelchair:description',
#  'wikidata',
#  'wikipedia',
#  'wikipedia:ru',
#  'geometry']

# %%
target_list_of_columns = ['id', 'addr:city', 'addr:full', 'addr:housenumber', 'addr:postcode', 'addr:street', 'addr:place',
                          'amenity', 'building', 'building:levels', 'name', 'type', 'short_name', 'old_name', 'website',
                          'contact:website', 'official_name', 'capacity', 'url', 'geometry']

# %%
drop_list_of_columns = []
for i in full_list_of_columns:
  if i not in target_list_of_columns:
    drop_list_of_columns.append(i)
drop_list_of_columns
# Out:
# ['@id',
#  'access',
#  'access:conditional',
#  'addr:country',
#  'addr:housenumber1',
#  'addr:housenumber2',
#  'addr:quarter',
#  'addr:region',
#  'addr:street1',
#  'addr:street2',
#  'addr:subdistrict',
#  'addr:suburb',
#  'after_school',
#  'alt_name',
#  'architect',
#  'barrier',
#  'bicycle',
#  'branch',
#  'building:colour',
#  'building:material',
#  'building:part',
#  'building:parts',
#  'check_date',
#  'check_date:opening_hours',
#  'comment',
#  'comment2',
#  'construction',
#  'contact:email',
#  'contact:facebook',
#  'contact:instagram',
#  'contact:phone',
#  'contact:telegram',
#  'contact:twitter',
#  'contact:vk',
#  'contact:website:en',
#  'contact:youtube',
#  'denomination',
#  'description',
#  'description:en',
#  'description:fr',
#  'description:ru',
#  'design:ref',
#  'disused',
#  'education',
#  'education_form:external',
#  'education_form:fulltime',
#  'education_form:parttime',
#  'education_level:preschool',
#  'education_level:primary',
#  'education_level:secondary',
#  'education_profile:biology',
#  'education_profile:chemistry',
#  'education_profile:economics',
#  'education_profile:general',
#  'education_profile:it',
#  'education_profile:languages',
#  'education_profile:mathematics',
#  'education_profile:military',
#  'education_profile:physics',
#  'education_profile:sport',
#  'education_programme:EN',
#  'education_programme:FR',
#  'education_system:ru_standard',
#  'email',
#  'fee',
#  'fence_type',
#  'fenced',
#  'fixme',
#  'full_name',
#  'grades',
#  'height',
#  'heritage',
#  'heritage:name',
#  'historic',
#  'image',
#  'int_name',
#  'internet_access',
#  'is_in:neighbourhood',
#  'isced:level',
#  'landuse',
#  'language:en',
#  'leisure',
#  'level',
#  'levels',
#  'material',
#  'min_age',
#  'mosuzedu',
#  '@relations',
#  'name:alt',
#  'name:de',
#  'name:en',
#  'name:etymology:wikidata',
#  'name:fi',
#  'name:fr',
#  'name:it',
#  'name:ja',
#  'name:old',
#  'name:ru',
#  'name:sv',
#  'note',
#  'old_name2',
#  'old_name:1',
#  'old_name:2',
#  'old_name:de',
#  'old_name:en',
#  'old_official_name',
#  'old_ref',
#  'old_ref:1',
#  'old_ref:2',
#  'old_website',
#  'opening_date',
#  'opening_hours',
#  'operator',
#  'operator:en',
#  'operator:ref:inn',
#  'operator:ref:kpp',
#  'operator:ref:ogrn',
#  'operator:type',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'ownership',
#  'pedagogy',
#  'phone',
#  'ref',
#  'religion',
#  'roof:angle',
#  'roof:colour',
#  'roof:height',
#  'roof:levels',
#  'roof:material',
#  'roof:shape',
#  'school',
#  'smoking',
#  'social_facility',
#  'social_facility:for',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:building:levels',
#  'sport',
#  'start_date',
#  'supervised',
#  'toilets:wheelchair',
#  'was:alt_name',
#  'was:name',
#  'website:en',
#  'wheelchair',
#  'wheelchair:description',
#  'wikidata',
#  'wikipedia',
#  'wikipedia:ru']

# %%
df_school.drop(drop_list_of_columns, axis=1, inplace=True)

# %%
updated_list_of_columns = df_school.columns.values.tolist()
updated_list_of_columns
# Out:
# ['id',
#  'addr:city',
#  'addr:full',
#  'addr:housenumber',
#  'addr:place',
#  'addr:postcode',
#  'addr:street',
#  'amenity',
#  'building',
#  'building:levels',
#  'capacity',
#  'contact:website',
#  'name',
#  'official_name',
#  'old_name',
#  'short_name',
#  'type',
#  'url',
#  'website',
#  'geometry']

# %%
df_school
# Out:
#                     id addr:city addr:full addr:housenumber addr:place  \
# 0       relation/36980    Москва       NaN           64А с2        NaN
# 1       relation/48572       NaN       NaN            28 к1        NaN
# 2       relation/62986       NaN       NaN               21        NaN
# 3       relation/62987       NaN       NaN               23        NaN
# 4      relation/286862       NaN       NaN            10 к2        NaN
# ...                ...       ...       ...              ...        ...
# 2112   node/9843601709       NaN       NaN              NaN        NaN
# 2113   node/9910450170       NaN       NaN              NaN        NaN
# 2114  node/10269753089       NaN       NaN            10 к1        NaN
# 2115  node/10593636787       NaN       NaN              NaN        NaN
# 2116  node/10709028671       NaN       NaN              NaN        NaN
#
#      addr:postcode             addr:street amenity building building:levels  \
# 0           127238       Хорошёвское шоссе  school      yes               3
# 1              NaN  улица Крылатские Холмы  school   school               3
# 2              NaN        Батайский проезд  school   school               3
# 3              NaN        Батайский проезд  school   school               3
# 4              NaN         улица Амундсена  school      yes               3
# ...            ...                     ...     ...      ...             ...
# 2112           NaN                     NaN  school      NaN             NaN
# 2113           NaN                     NaN  school      NaN             NaN
# 2114           NaN       Аэродромная улица  school      NaN             NaN
# 2115           NaN                     NaN  school      NaN             NaN
# 2116           NaN                     NaN  school      NaN             NaN
#
#      capacity contact:website                              name official_name  \
# 0         NaN             NaN                Школа №1288 (СП-5)           NaN
# 1         NaN             NaN                   Гимназия № 1593           NaN
# 2         NaN             NaN                      Школа № 1141           NaN
# 3         NaN             NaN                        Школа №499           NaN
# 4         NaN             NaN                               NaN           NaN
# ...       ...             ...                               ...           ...
# 2112      NaN             NaN  Детская художественная школа № 9           NaN
# 2113      NaN             NaN                      Атлас school           NaN
# 2114      NaN             NaN                              Плюс           NaN
# 2115      NaN             NaN                    Гимназия №1788           NaN
# 2116      NaN             NaN                         Подсолнух           NaN
#
#      old_name            short_name          type  url  \
# 0         NaN                   NaN  multipolygon  NaN
# 1         NaN  ГБОУ Гимназия № 1593  multipolygon  NaN
# 2         NaN                   NaN  multipolygon  NaN
# 3         NaN                   NaN  multipolygon  NaN
# 4         NaN                   NaN  multipolygon  NaN
# ...       ...                   ...           ...  ...
# 2112      NaN                   NaN           NaN  NaN
# 2113      NaN                   NaN           NaN  NaN
# 2114      NaN                   NaN           NaN  NaN
# 2115      NaN                   NaN           NaN  NaN
# 2116      NaN                   NaN           NaN  NaN
#
#                            website  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 2112                           NaN
# 2113                           NaN
# 2114           https://profplus.ru
# 2115  https://gum1788tn.mskobr.ru/
# 2116     http://centr-podsolnuh.ru
#
#                                                geometry
# 0     POLYGON ((37.52905 55.77856, 37.52898 55.77845...
# 1     POLYGON ((37.41419 55.76515, 37.41421 55.76503...
# 2     POLYGON ((37.71844 55.64383, 37.71844 55.64371...
# 3     POLYGON ((37.72010 55.64387, 37.72010 55.64375...
# 4     POLYGON ((37.65890 55.85376, 37.65873 55.85373...
# ...                                                 ...
# 2112                          POINT (37.16348 55.97818)
# 2113                          POINT (37.50742 55.69662)
# 2114                          POINT (37.43346 55.84703)
# 2115                          POINT (37.31470 55.63963)
# 2116                          POINT (37.59005 55.81845)
#
# [2117 rows x 20 columns]

# %%
#Заполняем пустые значение города Москвой
df_school['addr:city'] = df_school['addr:city'].fillna('Москва')

# %%
#Заполняем пустые значение посткода нулями
df_school['addr:postcode'] = df_school['addr:postcode'].fillna('000000')

# %%
#Заполняем поле amenity на school
df_school['amenity'] = df_school['amenity'].fillna('school')

# %%
#Заменяем поле building на school
df_school['building'] = df_school['building'].fillna('school')
df_school['building'].replace('yes', 'school', inplace=True)

# %%
(df_school.iloc[0]['addr:full'])
# Out:
# nan

# %%
#Заполнение addr:street из addr:place
df_school['addr:street'] = df_school['addr:street'].fillna('empty')
df_school['addr:place'] = df_school['addr:place'].fillna('empty')
for i in range(df_school.shape[0]):
  if df_school.iloc[i]['addr:street'] == 'empty' and df_school.iloc[i]['addr:place'] != 'empty':
    df_school.iloc[i]['addr:street'] = df_school.iloc[i]['addr:place']
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()

# %%
#Заполнение name из official_name	old_name	short_name
df_school['name'] = df_school['name'].fillna('empty')
df_school['official_name'] = df_school['official_name'].fillna('empty')
df_school['old_name'] = df_school['old_name'].fillna('empty')
df_school['short_name'] = df_school['short_name'].fillna('empty')
for i in range(df_school.shape[0]):
  if df_school.iloc[i]['name'] == 'empty' and df_school.iloc[i]['official_name'] != 'empty':
    df_school.iloc[i]['name'] = df_school.iloc[i]['official_name']
  elif df_school.iloc[i]['name'] == 'empty' and df_school.iloc[i]['short_name'] != 'empty':
    df_school.iloc[i]['name'] = df_school.iloc[i]['short_name']
  elif df_school.iloc[i]['name'] == 'empty' and df_school.iloc[i]['old_name'] != 'empty':
    df_school.iloc[i]['name'] = df_school.iloc[i]['old_name']

# %%
#Заполнение website из url contact:website
df_school['website'] = df_school['website'].fillna('empty')
df_school['url'] = df_school['url'].fillna('empty')
df_school['contact:website'] = df_school['contact:website'].fillna('empty')
for i in range(df_school.shape[0]):
  if df_school.iloc[i]['website'] == 'empty' and df_school.iloc[i]['url'] != 'empty':
    df_school.iloc[i]['website'] = df_school.iloc[i]['url']
  elif df_school.iloc[i]['website'] == 'empty' and df_school.iloc[i]['contact:website'] != 'empty':
    df_school.iloc[i]['website'] = df_school.iloc[i]['contact:website']

# %%
df_school
# Out:
#                     id addr:city addr:full addr:housenumber addr:place  \
# 0       relation/36980    Москва       NaN           64А с2      empty
# 1       relation/48572    Москва       NaN            28 к1      empty
# 2       relation/62986    Москва       NaN               21      empty
# 3       relation/62987    Москва       NaN               23      empty
# 4      relation/286862    Москва       NaN            10 к2      empty
# ...                ...       ...       ...              ...        ...
# 2112   node/9843601709    Москва       NaN              NaN      empty
# 2113   node/9910450170    Москва       NaN              NaN      empty
# 2114  node/10269753089    Москва       NaN            10 к1      empty
# 2115  node/10593636787    Москва       NaN              NaN      empty
# 2116  node/10709028671    Москва       NaN              NaN      empty
#
#      addr:postcode             addr:street amenity building building:levels  \
# 0           127238       Хорошёвское шоссе  school   school               3
# 1           000000  улица Крылатские Холмы  school   school               3
# 2           000000        Батайский проезд  school   school               3
# 3           000000        Батайский проезд  school   school               3
# 4           000000         улица Амундсена  school   school               3
# ...            ...                     ...     ...      ...             ...
# 2112        000000                   empty  school   school             NaN
# 2113        000000                   empty  school   school             NaN
# 2114        000000       Аэродромная улица  school   school             NaN
# 2115        000000                   empty  school   school             NaN
# 2116        000000                   empty  school   school             NaN
#
#      capacity contact:website                              name official_name  \
# 0         NaN           empty                Школа №1288 (СП-5)         empty
# 1         NaN           empty                   Гимназия № 1593         empty
# 2         NaN           empty                      Школа № 1141         empty
# 3         NaN           empty                        Школа №499         empty
# 4         NaN           empty                             empty         empty
# ...       ...             ...                               ...           ...
# 2112      NaN           empty  Детская художественная школа № 9         empty
# 2113      NaN           empty                      Атлас school         empty
# 2114      NaN           empty                              Плюс         empty
# 2115      NaN           empty                    Гимназия №1788         empty
# 2116      NaN           empty                         Подсолнух         empty
#
#      old_name            short_name          type    url  \
# 0       empty                 empty  multipolygon  empty
# 1       empty  ГБОУ Гимназия № 1593  multipolygon  empty
# 2       empty                 empty  multipolygon  empty
# 3       empty                 empty  multipolygon  empty
# 4       empty                 empty  multipolygon  empty
# ...       ...                   ...           ...    ...
# 2112    empty                 empty           NaN  empty
# 2113    empty                 empty           NaN  empty
# 2114    empty                 empty           NaN  empty
# 2115    empty                 empty           NaN  empty
# 2116    empty                 empty           NaN  empty
#
#                            website  \
# 0                            empty
# 1                            empty
# 2                            empty
# 3                            empty
# 4                            empty
# ...                            ...
# 2112                         empty
# 2113                         empty
# 2114           https://profplus.ru
# 2115  https://gum1788tn.mskobr.ru/
# 2116     http://centr-podsolnuh.ru
#
#                                                geometry
# 0     POLYGON ((37.52905 55.77856, 37.52898 55.77845...
# 1     POLYGON ((37.41419 55.76515, 37.41421 55.76503...
# 2     POLYGON ((37.71844 55.64383, 37.71844 55.64371...
# 3     POLYGON ((37.72010 55.64387, 37.72010 55.64375...
# 4     POLYGON ((37.65890 55.85376, 37.65873 55.85373...
# ...                                                 ...
# 2112                          POINT (37.16348 55.97818)
# 2113                          POINT (37.50742 55.69662)
# 2114                          POINT (37.43346 55.84703)
# 2115                          POINT (37.31470 55.63963)
# 2116                          POINT (37.59005 55.81845)
#
# [2117 rows x 20 columns]

# %%
#Удаление колонок, которые больше не пригодятся
addititonal_dropping_columns = ['addr:full', 'addr:place', 'short_name', 'contact:website', 'url', 'old_name', 'official_name']
df_school.drop(addititonal_dropping_columns, axis=1, inplace=True)

# %%
#Заполнение оставшихся пустых данных нулевыми значениями
df_school['building:levels'] = df_school['building:levels'].fillna('0')
df_school['capacity'] = df_school['capacity'].fillna('0')

# %%
#Добавление данных о количестве студентов
df_school['students_number'] = ""
df_school['students_number'] = df_school['students_number'].replace('', '0')

# %%
df_school
# Out:
#                     id addr:city addr:housenumber addr:postcode  \
# 0       relation/36980    Москва           64А с2        127238
# 1       relation/48572    Москва            28 к1        000000
# 2       relation/62986    Москва               21        000000
# 3       relation/62987    Москва               23        000000
# 4      relation/286862    Москва            10 к2        000000
# ...                ...       ...              ...           ...
# 2112   node/9843601709    Москва              NaN        000000
# 2113   node/9910450170    Москва              NaN        000000
# 2114  node/10269753089    Москва            10 к1        000000
# 2115  node/10593636787    Москва              NaN        000000
# 2116  node/10709028671    Москва              NaN        000000
#
#                  addr:street amenity building building:levels capacity  \
# 0          Хорошёвское шоссе  school   school               3        0
# 1     улица Крылатские Холмы  school   school               3        0
# 2           Батайский проезд  school   school               3        0
# 3           Батайский проезд  school   school               3        0
# 4            улица Амундсена  school   school               3        0
# ...                      ...     ...      ...             ...      ...
# 2112                   empty  school   school               0        0
# 2113                   empty  school   school               0        0
# 2114       Аэродромная улица  school   school               0        0
# 2115                   empty  school   school               0        0
# 2116                   empty  school   school               0        0
#
#                                   name          type  \
# 0                   Школа №1288 (СП-5)  multipolygon
# 1                      Гимназия № 1593  multipolygon
# 2                         Школа № 1141  multipolygon
# 3                           Школа №499  multipolygon
# 4                                empty  multipolygon
# ...                                ...           ...
# 2112  Детская художественная школа № 9           NaN
# 2113                      Атлас school           NaN
# 2114                              Плюс           NaN
# 2115                    Гимназия №1788           NaN
# 2116                         Подсолнух           NaN
#
#                            website  \
# 0                            empty
# 1                            empty
# 2                            empty
# 3                            empty
# 4                            empty
# ...                            ...
# 2112                         empty
# 2113                         empty
# 2114           https://profplus.ru
# 2115  https://gum1788tn.mskobr.ru/
# 2116     http://centr-podsolnuh.ru
#
#                                                geometry students_number
# 0     POLYGON ((37.52905 55.77856, 37.52898 55.77845...               0
# 1     POLYGON ((37.41419 55.76515, 37.41421 55.76503...               0
# 2     POLYGON ((37.71844 55.64383, 37.71844 55.64371...               0
# 3     POLYGON ((37.72010 55.64387, 37.72010 55.64375...               0
# 4     POLYGON ((37.65890 55.85376, 37.65873 55.85373...               0
# ...                                                 ...             ...
# 2112                          POINT (37.16348 55.97818)               0
# 2113                          POINT (37.50742 55.69662)               0
# 2114                          POINT (37.43346 55.84703)               0
# 2115                          POINT (37.31470 55.63963)               0
# 2116                          POINT (37.59005 55.81845)               0
#
# [2117 rows x 14 columns]

# %%
#Запись в файл
df_school.to_file('schools.geojson', driver="GeoJSON")
